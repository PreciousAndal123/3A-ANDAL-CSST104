# %% [markdown]
# # 1. Creating Datasets

# %%
import pandas as pd

data = {
    'student_id': range (1,21),
    'gender': ['Male','','Male','Female','Male','Female','Male','Female','Male','Female','Male','Female','Male','Female','Male','Female','Male','Female','Male','Female'],
    'test_date': pd.date_range(start='2024-02-21',periods=20),
    'study_hours': [2,3,4,5,6,7,8,9,20,22,13,2,1,2,3,4,5,6,7,8],
    'test_score': [100,98,88,91,90,84,82,77,99,85,89,94,100,98,88,91,90,84,82,77],
    'attendance': ['Present','','Present','','Present','Absent','Absent','Present','Present','Present','Present','Present','Present','Present','Present','Present','Present','Present','Absent','Absent']

}

df = pd.DataFrame(data)

df.to_csv('student_performance.csv', index=False)

# %% [markdown]
# # 2.  Data Loading and Initial Examination

# %%
#Load Dataset
df = pd.read_csv('student_performance.csv')

#Print Dataset
print(df.head(15))

#
print(df.isnull().sum())
# Out:
#     student_id  gender   test_date  study_hours  test_score attendance
# 0            1    Male  2024-02-21            2         100    Present
# 1            2     NaN  2024-02-22            3          98        NaN
# 2            3    Male  2024-02-23            4          88    Present
# 3            4  Female  2024-02-24            5          91        NaN
# 4            5    Male  2024-02-25            6          90    Present
# 5            6  Female  2024-02-26            7          84     Absent
# 6            7    Male  2024-02-27            8          82     Absent
# 7            8  Female  2024-02-28            9          77    Present
# 8            9    Male  2024-02-29           20          99    Present
# 9           10  Female  2024-03-01           22          85    Present
# 10          11    Male  2024-03-02           13          89    Present
# 11          12  Female  2024-03-03            2          94    Present
# ...

# %% [markdown]
# # 3. EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sne

#Compute Summary Stats
summary_stats  = df[['test_score', 'study_hours']].describe()

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sne.histplot(df['test_score'], bins=15,kde=True)
plt.title('Distribution of Test Score')

plt.subplot(1,2,2)
sne.histplot(df['study_hours'], bins=15,kde=True)
plt.title('Distribution of Study Hours')

plt.figure(figsize=(8,6))
sne.scatterplot(data=df, x='study_hours', y='test_score')
plt.title('Scatter Plot of Study Hours vs. Test Score')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Study Hours vs. Test Score')
